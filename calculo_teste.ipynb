# %%
import pandas as pd
import openpyxl as pyxl
import numpy as np

# %%
df_viagem = pd.read_excel('VIAGENS_JMS.XLSX')

#display(df_viagem.head())
#display(df_viagem.describe())

df_viagem_resumo = df_viagem[['Número do pedido JMS' , 'Estação de entrega' , 'Correio de entrega' , 'Tempo de entrega' , 
'Marca de assinatura' , 'Peso cobrável' , 'Cidade destinatário' , 'CEP do destino']]

transpo = ['BTU 01' , 'ARA 01' , 'BRG 01']

df_realizada = df_viagem_resumo.loc[(df_viagem_resumo['Marca de assinatura'] == 'Recebimento com assinatura normal')]

display(df_realizada)
# Out:
#        Número do pedido JMS Estação de entrega  \
# 0           888500005263494             BRG 01
# 1           888500003121358             BRG 01
# 2           888500000087541             BRG 01
# 3           888500009881243             BTU 01
# 4           888500009646724             BTU 01
# ...                     ...                ...
# 40518       888500012515194             ARA 01
# 40519       888500011937574             ARA 01
# 40520       888500020281047             ARA 01
# 40521       888500019588825             ARA 01
# 40522       888500019099305             ARA 01
#
#                        Correio de entrega     Tempo de entrega  \
# 0      CHT - DANIEL ROSA MARIANO DA SILVA  2022-10-01 10:12:46
# 1      CHT - DANIEL ROSA MARIANO DA SILVA  2022-10-01 10:12:58
# 2      CHT - DANIEL ROSA MARIANO DA SILVA  2022-10-01 10:12:51
# 3                            EVA CRISTINA  2022-10-01 09:40:33
# 4                            EVA CRISTINA  2022-10-01 09:41:01
# ...

# %%
df_transportadoras = pd.read_excel('TRANSPORTADORAS_JMS.xlsx')

transportadoras = df_transportadoras['JMS'].unique().tolist() 

display (transportadoras)
# Out:
# ['SJK 01',
#  'SOD 03',
#  'VXE 01',
#  'BAU 01',
#  'HOT 01',
#  'BRG 01',
#  'SAO 12',
#  'SAO 13',
#  'MGM 01',
#  'SAO 16',
#  'GRU 03',
#  'QHB 01',
#  'SAO 17',
#  'SAO 15',
#  'CGT 01',
#  'JDI 01',
#  'RGT 01',
#  'PPB 01',
#  'ITQ 01',
#  'GUJ 01',
#  'MCC 01',
#  'BTU 01',
#  'SJP 02',
#  'JBL 01',
#  'ARA 01',
#  'SAO 14',
#  'AQA 01',
#  'RAO 01',
#  'SJP 01',
#  'SJK 02',
#  'ARA 02']
